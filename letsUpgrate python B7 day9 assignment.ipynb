# %%
! pip install pylint
# Out:
# Collecting pylint
#   Downloading pylint-2.6.0-py3-none-any.whl (325 kB)
#      |████████████████████████████████| 325 kB 3.1 MB/s eta 0:00:01
# Collecting toml>=0.7.1
#   Downloading toml-0.10.1-py2.py3-none-any.whl (19 kB)
# Collecting astroid<=2.5,>=2.4.0
#   Downloading astroid-2.4.2-py3-none-any.whl (213 kB)
#      |████████████████████████████████| 213 kB 10.7 MB/s eta 0:00:01
# Collecting mccabe<0.7,>=0.6
#   Downloading mccabe-0.6.1-py2.py3-none-any.whl (8.6 kB)
# Collecting isort<6,>=4.2.5
#   Downloading isort-5.5.2-py3-none-any.whl (95 kB)
#      |████████████████████████████████| 95 kB 2.0 MB/s  eta 0:00:01
# Requirement already satisfied: six~=1.12 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from astroid<=2.5,>=2.4.0->pylint) (1.15.0)
# Collecting typed-ast<1.5,>=1.4.0; implementation_name == "cpython" and python_version < "3.8"
#   Downloading typed_ast-1.4.1-cp37-cp37m-manylinux1_x86_64.whl (737 kB)
#      |████████████████████████████████| 737 kB 11.3 MB/s eta 0:00:01
# Collecting lazy-object-proxy==1.4.*
#   Downloading lazy_object_proxy-1.4.3-cp37-cp37m-manylinux1_x86_64.whl (56 kB)
#      |████████████████████████████████| 56 kB 4.5 MB/s  eta 0:00:01
# Collecting wrapt~=1.11
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Building wheels for collected packages: wrapt
#   Building wheel for wrapt (setup.py) ... done
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp37-cp37m-linux_x86_64.whl size=36044 sha256=645d5ec37c047600e7d21696f50c609739487c1a928d5dda56a1ed8853a77fa7
#   Stored in directory: /home/jovyan/.cache/pip/wheels/62/76/4c/aa25851149f3f6d9785f6c869387ad82b3fd37582fa8147ac6
# Successfully built wrapt
# Installing collected packages: toml, typed-ast, lazy-object-proxy, wrapt, astroid, mccabe, isort, pylint
# Successfully installed astroid-2.4.2 isort-5.5.2 lazy-object-proxy-1.4.3 mccabe-0.6.1 pylint-2.6.0 toml-0.10.1 typed-ast-1.4.1 wrapt-1.12.1

# %%
# %%writefile prime.txt
#
# '''this function is made to check input_no if it is
# input_no prime number or not
# '''
#
# def isprime():
#     ''' rhis is function is doing Aall the checking'''
#
#     print(" enter input_no number to check whether it is prime or not:")
#
#           input_no=int(input())
#     if input_no>1:
#         for help_no in range (2,input_no):
#             if (input_no%help_no)==0:
#                 print(help_no,'times',input_no//help_no,'is',input_no)
#                 print("is not prime number")
#                 break
#             else:
#                 print (input_no,'is prime number')
#                     overwriting prime.txt
# Out:
# Overwriting prime.txt

# %%
# !pylint prime.txt
# Out:
# ************* Module prime
# prime.txt:11:10: E0001: unexpected indent (<unknown>, line 11) (syntax-error)

# %%
#Question 2

# %%
def Armstrong ():
    print("Armstrong number in range of 1 to 1000are:")
    for x in range (1,1001):
        sum =0
        order=len(str(x))
        temp=x
        while temp>0:
            digit=temp%10
            sum+=digit**order
            temp//=10
            if x==sum:
                yield(x)
                list(Armstrong
# Out:
#   File "<ipython-input-28-d51c9a709846>", line 13
#     list(Armstrong
#                    ^
# SyntaxError: unexpected EOF while parsing

# %%
list(Armstrong())
# Out:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# ...
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# Armstrong number in range of 1 to 1000are:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-29-f125a8f2936e> in <module>
# ----> 1 list(Armstrong())
#
# <ipython-input-25-996ed683a79c> in Armstrong()
#      11             if x==sum:
#      12                 yield(x)
# ---> 13                 list(Armstrong ())
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-25-996ed683a79c> in Armstrong()
#      11             if x==sum:
#      12                 yield(x)
# ---> 13                 list(Armstrong ())
#
# RecursionError: maximum recursion depth exceeded
